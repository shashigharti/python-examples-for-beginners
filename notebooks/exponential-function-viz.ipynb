# %%
import matplotlib
from matplotlib import pyplot as plt
matplotlib.__version__
# Out:
# '3.1.3'

# %%
from packages import exponentials
import numpy as np
import math

# %%
### Generate points and plot the graph for equation y=e**x ###

x_rng = [1, 12]
yfunc = lambda x: math.exp(x)
y = exponentials.generate(yfunc, rng = x_rng)
x = list(range(*x_rng))
plt.figure()
plt.plot(x, y)
plt.xlabel("$x$")
plt.ylabel("$\exp(x)$")
plt.title("Graph for equation $y=e^{x}$")
# Out:
# Text(0.5, 1.0, 'Graph for equation $y=e^{x}$')

# %%
### Generate points and plot the graph for equation y=e**-x ###

x_rng = [1, 12]
yfunc = lambda x: math.exp(-x)
y = exponentials.generate(yfunc, rng = x_rng)
x = list(range(*x_rng))
plt.figure()
plt.plot(x, y)
plt.xlabel("$x$")
plt.ylabel("$\exp(-x)$")
plt.title("Graph for equation $y=e^{-x}$")
# Out:
# Text(0.5, 1.0, 'Graph for equation $y=e^{-x}$')
