# %% [markdown]
# <h1> Exploring Functions: Linear, Exponential and Quadratic </h1>

# %%
### To include packages folder path
import sys, os
sys.path.insert(0, os.path.abspath('') + "/../")

# %%
import matplotlib
from matplotlib import pyplot as plt
matplotlib.__version__
# Out:
# '3.1.3'

# %%
from packages import functions
import numpy as np
import math

# %% [markdown]
# <h2>Exponential Function And Its Graph</h2>

# %%
### Generate points and plot the graph for equation y=e**x ###

x_rng = [-10, 12]
f = lambda x: math.exp(x)
x,y = functions.generate(f, rng = x_rng)
functions.plot_graph(x, y, label_y = "$\exp(x)$", label_x = "$x", title = "Graph for equation $y=e^{x}$")

# %% [markdown]
# <h2>Linear Function And Its Graph</h2>

# %%
### Generate points and plot the graph for equation y=mx + c ###

x_rng = [-10, 12]

# slope and intercept
m = 2.5
c = 10 

# Generate Data
f = lambda x: m*x + c
x, y = functions.generate(f, rng = x_rng)
functions.plot_graph(x, y, label_y = "$mx + c$", label_x = "$x", title = "Graph for equation $y=mx + c$")

# %% [markdown]
# <h2>Quadratic Function And Its Graph<h2>

# %%
### Generate points and plot the graph for equation y=mx + c ###

x_rng = [-10, 12]

# Generate Data
f = lambda x: x**2
x, y = functions.generate(f, rng = x_rng)
functions.plot_graph(x, y, label_y = "$x**2$", label_x = "$x", title = "Graph for equation $x**2")
